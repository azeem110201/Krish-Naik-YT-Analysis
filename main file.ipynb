# %%
from apiclient.discovery import build
api_key = "AIzaSyB24piWGmosu2vOQzjlmaWg8DHCV7ahNcI"
youtube = build(serviceName='youtube',version='v3',developerKey=api_key)

# %%
def get_channel_videos(channel_name):
    
    res = youtube.channels().list(forUsername=channel_name,part='contentDetails').execute()
    
    channel_id = res['items'][0]['id']
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
result = get_channel_videos("krishNaik06")

# %%
def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics,contentDetails,snippet').execute()
        stats += res['items']
        
    return stats

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], result))

# %%
stats = get_videos_stats(video_ids)

# %%
stats
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'a9AjSCr1H9a7rESbVdsQgfkvuEo',
#   'id': 'UXV_o2W_UUA',
#   'snippet': {'publishedAt': '2021-01-05T10:15:46Z',
#    'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#    'title': 'Advanced Python Series- Custom Exception Handling In Python',
# ...

# %%
stats_len = len(stats)

# %%
stats[0]['snippet']['tags']
# Out:
# ['exception handling in python example',
#  'exception handling in python pdf',
#  'python catch all exceptions',
#  'python except exception as e',
#  'exception handling in python w3schools',
#  'user defined exception in python',
#  'python exception class',
#  'python exception message']

# %%
all_stats = list()

for i in range(stats_len):
    video = stats[i]['id']
    video_link = "https://www.youtube.com/watch?v={}&ab_channel=KrishNaik".format(video)
    title = stats[i]['snippet']['title']
    description = stats[i]['snippet']['description']
    #tags = stats[i]['snippet']['tags']
    duration = stats[i]['contentDetails']['duration']
    dimension = stats[i]['contentDetails']['dimension']
    definition = stats[i]['contentDetails']['definition']
    caption = stats[i]['contentDetails']['caption']
    licensedContent = stats[i]['contentDetails']['licensedContent']
    viewCount = stats[i]['statistics']['viewCount']
    likeCount = stats[i]['statistics']['likeCount']
    dislikeCount = stats[i]['statistics']['dislikeCount']
    favoriteCount = stats[i]['statistics']['favoriteCount']
    commentCount = stats[i]['statistics']['commentCount']
    
    content = {
        "video_id":video,
        "video_link":video_link,
        "title":title,
        "description":description,
        #"tags":tags,
        "duration":duration,
        "dimension":dimension,
        "definition":definition,
        "caption":caption,
        "licensedContent":licensedContent,
        "viewCount":viewCount,
        "likeCount":likeCount,
        "dislikeCount":dislikeCount,
        "favoriteCount":favoriteCount,
        "commentCount":commentCount
    }
    
    all_stats.append(content)

# %%
all_stats[0]
# Out:
# {'video_id': 'UXV_o2W_UUA',
#  'video_link': 'https://www.youtube.com/watch?v=UXV_o2W_UUA&ab_channel=KrishNaik',
#  'title': 'Advanced Python Series- Custom Exception Handling In Python',
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame()
data['video_id'] = np.nan
data['video_link'] = np.nan
data['title'] = np.nan
data['description'] = np.nan
data['duration'] = np.nan
data['dimension'] = np.nan
data['definition'] = np.nan
data['caption'] = np.nan
data['licensedContent'] = np.nan
data['viewCount'] = np.nan
data['likeCount'] = np.nan
data['dislikeCount'] = np.nan
data['favoriteCount'] = np.nan
data['commentCount'] = np.nan

# %%
for value in all_stats[0].values():
    print(value)
# Out:
# UXV_o2W_UUA
# https://www.youtube.com/watch?v=UXV_o2W_UUA&ab_channel=KrishNaik
# Advanced Python Series- Custom Exception Handling In Python
# github: https://github.com/krishnaik06/Machine-Learning-in-90-days/blob/master/Section%201-%20Python%20Crash%20Course/Advanced%20Python%20Exception1.ipynb
# ⭐ Kite is a free AI-powered coding assistant that will help you code faster and smarter. The Kite plugin integrates with all the top editors and IDEs to give you smart completions and documentation while you’re typing. I've been using Kite for a few months and I love it! https://www.kite.com/get-kite/?utm_medium=referral&utm_source=youtube&utm_campaign=krishnaik&utm_content=description-only
#
# Starter In  Data Science
#
# 1  Complete Machine Learning Playlist:(Top 24 videos)
#
# https://www.youtube.com/playlist?list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe
#
# 2  Statistics in Machine Learning:(Understand some Concepts With Respect To Data)- Complete Playlist
# ...

# %%
data.columns
# Out:
# Index(['video_id', 'video_link', 'title', 'description', 'duration',
#        'dimension', 'definition', 'caption', 'licensedContent', 'viewCount',
#        'likeCount', 'dislikeCount', 'favoriteCount', 'commentCount'],
#       dtype='object')

# %%
# %%time

for i in range(len(all_stats)):
    data.loc[i, 'video_id'] = all_stats[i]['video_id']
    data.loc[i, 'video_link'] = all_stats[i]['video_link']
    data.loc[i, 'title'] = all_stats[i]['title']
    data.loc[i, 'description'] = all_stats[i]['description']
    data.loc[i, 'duration'] = all_stats[i]['duration']
    data.loc[i, 'dimension'] = all_stats[i]['dimension']
    data.loc[i, 'definition'] = all_stats[i]['definition']
    data.loc[i, 'caption'] = all_stats[i]['caption']
    data.loc[i, 'licensedContent'] = all_stats[i]['licensedContent']
    data.loc[i, 'viewCount'] = all_stats[i]['viewCount']
    data.loc[i, 'likeCount'] = all_stats[i]['likeCount']
    data.loc[i, 'dislikeCount'] = all_stats[i]['dislikeCount']
    data.loc[i, 'favoriteCount'] = all_stats[i]['favoriteCount']
    data.loc[i, 'commentCount'] = all_stats[i]['commentCount']
# Out:
# Wall time: 5.32 s

# %%
data.shape
# Out:
# (827, 14)

# %%
data
# Out:
#         video_id                                         video_link  \
# 0    UXV_o2W_UUA  https://www.youtube.com/watch?v=UXV_o2W_UUA&ab...
# 1    06HauGzxc9s  https://www.youtube.com/watch?v=06HauGzxc9s&ab...
# 2    dbc63VIpq60  https://www.youtube.com/watch?v=dbc63VIpq60&ab...
# 3    dmg5kZBCYck  https://www.youtube.com/watch?v=dmg5kZBCYck&ab...
# 4    dvVegQmxc60  https://www.youtube.com/watch?v=dvVegQmxc60&ab...
# ..           ...                                                ...
# 822  MTiaCUh1420  https://www.youtube.com/watch?v=MTiaCUh1420&ab...
# 823  DeT8mji0Jos  https://www.youtube.com/watch?v=DeT8mji0Jos&ab...
# 824  HrHJUc26YxI  https://www.youtube.com/watch?v=HrHJUc26YxI&ab...
# 825  EqRsD3gqeCo  https://www.youtube.com/watch?v=EqRsD3gqeCo&ab...
# 826  qMLxWX49i8I  https://www.youtube.com/watch?v=qMLxWX49i8I&ab...
#
#                                                  title  \
# 0    Advanced Python Series- Custom Exception Handl...
# ...

# %%
data.isnull().sum()
# Out:
# video_id           0
# video_link         0
# title              0
# description        0
# duration           0
# dimension          0
# definition         0
# caption            0
# licensedContent    0
# viewCount          0
# likeCount          0
# dislikeCount       0
# favoriteCount      0
# commentCount       0
# dtype: int64

# %%
data.to_csv("krish.csv")
